# %%
# Challenge 6.1.3
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Challenge 6.1.3
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Challenge 6.1.3
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Challenge 6.1.4
from citipy import citipy

# %%
# Challenge 6.1.4
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Challenge 6.1.5
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Challenge 6.1.5
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Challenge 6.1.6
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pangnirtung
# Processing Record 2 of Set 1 | sitka
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | sumbe
# Processing Record 7 of Set 1 | deputatskiy
# Processing Record 8 of Set 1 | devgarh
# Processing Record 9 of Set 1 | shurugwi
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | constantine
# Processing Record 12 of Set 1 | sale
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | kloulklubed
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | broken hill
# Processing Record 17 of Set 1 | neiafu
# Processing Record 18 of Set 1 | aswan
# Processing Record 19 of Set 1 | sault sainte marie
# Processing Record 20 of Set 1 | ewa beach
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | saint-andre-les-vergers
# Processing Record 23 of Set 1 | cabedelo
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | soldotna
# Processing Record 26 of Set 1 | vagur
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | ossora
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | kattivakkam
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | lugovoy
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | necochea
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | san jose
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | ostrovnoy
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | warrington
# Processing Record 48 of Set 1 | hamilton
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | northam
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 2 | la ronge
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | tatarsk
# Processing Record 12 of Set 2 | black river
# Processing Record 13 of Set 2 | bilma
# Processing Record 14 of Set 2 | kotri
# Processing Record 15 of Set 2 | pochutla
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | bandundu
# Processing Record 19 of Set 2 | houma
# Processing Record 20 of Set 2 | college
# Processing Record 21 of Set 2 | mormugao
# Processing Record 22 of Set 2 | pisco
# Processing Record 23 of Set 2 | hami
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | mastic beach
# Processing Record 26 of Set 2 | tual
# Processing Record 27 of Set 2 | talaya
# Processing Record 28 of Set 2 | havoysund
# Processing Record 29 of Set 2 | roros
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | santiago
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | spirit river
# Processing Record 34 of Set 2 | jining
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | kuhdasht
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | rafraf
# Processing Record 40 of Set 2 | bijela
# Processing Record 41 of Set 2 | east wenatchee bench
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 44 of Set 2 | mandalgovi
# Processing Record 45 of Set 2 | hualmay
# Processing Record 46 of Set 2 | tabuny
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | olafsvik
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | zaozhuang
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | yulara
# Processing Record 3 of Set 3 | kerman
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | les escoumins
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | eureka
# Processing Record 11 of Set 3 | leh
# Processing Record 12 of Set 3 | chowchilla
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | boa vista
# Processing Record 16 of Set 3 | manoel urbano
# Processing Record 17 of Set 3 | ningbo
# Processing Record 18 of Set 3 | bell ville
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | qaqortoq
# Processing Record 21 of Set 3 | burica
# City not found. Skipping...
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | brovst
# Processing Record 25 of Set 3 | husavik
# Processing Record 26 of Set 3 | amstetten
# Processing Record 27 of Set 3 | tazovskiy
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | terrace
# Processing Record 30 of Set 3 | morondava
# Processing Record 31 of Set 3 | sangar
# Processing Record 32 of Set 3 | touros
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | chalus
# Processing Record 35 of Set 3 | gat
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | mayo
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | carballo
# Processing Record 40 of Set 3 | lebu
# Processing Record 41 of Set 3 | san policarpo
# Processing Record 42 of Set 3 | adrar
# Processing Record 43 of Set 3 | wahiawa
# Processing Record 44 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 3 | maceio
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | sukhoy log
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | surt
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | baherden
# Processing Record 3 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 4 | salalah
# Processing Record 6 of Set 4 | roshchino
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | berlevag
# Processing Record 9 of Set 4 | snezhnogorsk
# Processing Record 10 of Set 4 | jiaohe
# Processing Record 11 of Set 4 | waw
# Processing Record 12 of Set 4 | qaanaaq
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | vaini
# Processing Record 15 of Set 4 | chornukhy
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | shieli
# Processing Record 18 of Set 4 | moose factory
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | jutai
# Processing Record 21 of Set 4 | wajir
# Processing Record 22 of Set 4 | noumea
# Processing Record 23 of Set 4 | ulladulla
# Processing Record 24 of Set 4 | tateyama
# Processing Record 25 of Set 4 | matara
# Processing Record 26 of Set 4 | codrington
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | bartica
# Processing Record 29 of Set 4 | torun
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | kartaly
# Processing Record 32 of Set 4 | kaeo
# Processing Record 33 of Set 4 | ingham
# Processing Record 34 of Set 4 | kinablangan
# Processing Record 35 of Set 4 | kamenka
# Processing Record 36 of Set 4 | sao sebastiao
# Processing Record 37 of Set 4 | yalova
# Processing Record 38 of Set 4 | grand baie
# Processing Record 39 of Set 4 | camocim
# Processing Record 40 of Set 4 | sambava
# Processing Record 41 of Set 4 | puerto madryn
# Processing Record 42 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 4 | vinh yen
# Processing Record 44 of Set 4 | basco
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | abu kamal
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | gondar
# Processing Record 2 of Set 5 | tsiroanomandidy
# Processing Record 3 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 5 | beloha
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | auki
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | dikson
# Processing Record 9 of Set 5 | prince rupert
# Processing Record 10 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 5 | mount gambier
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | epe
# Processing Record 16 of Set 5 | yakeshi
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 5 | kurchum
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | teya
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | jalu
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | baruun-urt
# Processing Record 26 of Set 5 | padang
# Processing Record 27 of Set 5 | kurayoshi
# Processing Record 28 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 5 | kemijarvi
# Processing Record 30 of Set 5 | agadez
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | bilibino
# Processing Record 33 of Set 5 | moerai
# Processing Record 34 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 35 of Set 5 | canton
# Processing Record 36 of Set 5 | virden
# Processing Record 37 of Set 5 | khilok
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | kodiak
# Processing Record 40 of Set 5 | baniachang
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | paamiut
# Processing Record 43 of Set 5 | benguela
# Processing Record 44 of Set 5 | vestmannaeyjar
# Processing Record 45 of Set 5 | atmakur
# Processing Record 46 of Set 5 | yagodnoye
# Processing Record 47 of Set 5 | gladstone
# Processing Record 48 of Set 5 | dzheguta
# Processing Record 49 of Set 5 | oksfjord
# Processing Record 50 of Set 5 | zheleznodorozhnyy
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | omboue
# Processing Record 3 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 4 of Set 6 | boyuibe
# Processing Record 5 of Set 6 | buala
# Processing Record 6 of Set 6 | upernavik
# Processing Record 7 of Set 6 | nikolskoye
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | dhidhdhoo
# Processing Record 10 of Set 6 | eagle
# Processing Record 11 of Set 6 | shumikha
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | flinders
# Processing Record 14 of Set 6 | maniitsoq
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | mana
# Processing Record 17 of Set 6 | havelock
# Processing Record 18 of Set 6 | saskylakh
# Processing Record 19 of Set 6 | kidodi
# Processing Record 20 of Set 6 | sinazongwe
# Processing Record 21 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | demba
# Processing Record 24 of Set 6 | banda aceh
# Processing Record 25 of Set 6 | demyansk
# Processing Record 26 of Set 6 | kismayo
# Processing Record 27 of Set 6 | aljezur
# Processing Record 28 of Set 6 | waingapu
# Processing Record 29 of Set 6 | amapa
# Processing Record 30 of Set 6 | nelson bay
# Processing Record 31 of Set 6 | moyale
# Processing Record 32 of Set 6 | seoul
# Processing Record 33 of Set 6 | lebedinyy
# Processing Record 34 of Set 6 | port hardy
# Processing Record 35 of Set 6 | cabo san lucas
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | srednekolymsk
# Processing Record 38 of Set 6 | svetlyy
# Processing Record 39 of Set 6 | asyut
# Processing Record 40 of Set 6 | san rafael
# Processing Record 41 of Set 6 | nanortalik
# Processing Record 42 of Set 6 | beitbridge
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | kaitangata
# Processing Record 46 of Set 6 | oussouye
# Processing Record 47 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 6 | tambura
# Processing Record 49 of Set 6 | hasaki
# Processing Record 50 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 7 | rajmahal
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | pacifica
# Processing Record 4 of Set 7 | muscat
# Processing Record 5 of Set 7 | majagual
# Processing Record 6 of Set 7 | biak
# Processing Record 7 of Set 7 | lipin bor
# Processing Record 8 of Set 7 | vila do maio
# Processing Record 9 of Set 7 | hengyang
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | baghdad
# Processing Record 12 of Set 7 | banfora
# Processing Record 13 of Set 7 | arrecife
# Processing Record 14 of Set 7 | los mochis
# Processing Record 15 of Set 7 | kosino
# Processing Record 16 of Set 7 | pokhara
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | rio gallegos
# Processing Record 19 of Set 7 | buin
# Processing Record 20 of Set 7 | huarmey
# Processing Record 21 of Set 7 | shu
# Processing Record 22 of Set 7 | fort nelson
# Processing Record 23 of Set 7 | aripuana
# Processing Record 24 of Set 7 | micco
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | yazman
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | borba
# Processing Record 29 of Set 7 | viedma
# Processing Record 30 of Set 7 | port augusta
# Processing Record 31 of Set 7 | la asuncion
# Processing Record 32 of Set 7 | mount isa
# Processing Record 33 of Set 7 | haines junction
# Processing Record 34 of Set 7 | mercedes
# Processing Record 35 of Set 7 | tharad
# Processing Record 36 of Set 7 | gariaband
# Processing Record 37 of Set 7 | mae hong son
# Processing Record 38 of Set 7 | kencong
# Processing Record 39 of Set 7 | tongchuan
# Processing Record 40 of Set 7 | roald
# Processing Record 41 of Set 7 | kecskemet
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | sabang
# Processing Record 44 of Set 7 | chapais
# Processing Record 45 of Set 7 | talcahuano
# Processing Record 46 of Set 7 | meiktila
# Processing Record 47 of Set 7 | tebingtinggi
# Processing Record 48 of Set 7 | tilichiki
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | kumi
# Processing Record 1 of Set 8 | oistins
# Processing Record 2 of Set 8 | kulhudhuffushi
# Processing Record 3 of Set 8 | luwuk
# Processing Record 4 of Set 8 | taganak
# Processing Record 5 of Set 8 | salimpur
# Processing Record 6 of Set 8 | wadi musa
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | luderitz
# Processing Record 9 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 8 | halifax
# Processing Record 11 of Set 8 | marshall
# Processing Record 12 of Set 8 | san carlos
# Processing Record 13 of Set 8 | port-gentil
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | kudat
# Processing Record 16 of Set 8 | jinka
# Processing Record 17 of Set 8 | kuching
# Processing Record 18 of Set 8 | oktyabrskiy
# Processing Record 19 of Set 8 | tibati
# Processing Record 20 of Set 8 | panzhihua
# Processing Record 21 of Set 8 | bandarbeyla
# Processing Record 22 of Set 8 | bamiantong
# Processing Record 23 of Set 8 | san miguelito
# Processing Record 24 of Set 8 | markivka
# Processing Record 25 of Set 8 | defiance
# Processing Record 26 of Set 8 | kirovskiy
# Processing Record 27 of Set 8 | lasa
# Processing Record 28 of Set 8 | lensk
# Processing Record 29 of Set 8 | mithi
# Processing Record 30 of Set 8 | richards bay
# Processing Record 31 of Set 8 | vilhena
# Processing Record 32 of Set 8 | nokia
# Processing Record 33 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | kelvington
# Processing Record 35 of Set 8 | ust-nera
# Processing Record 36 of Set 8 | fernie
# Processing Record 37 of Set 8 | umm bab
# Processing Record 38 of Set 8 | sinnamary
# Processing Record 39 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 8 | mahebourg
# Processing Record 41 of Set 8 | dukat
# Processing Record 42 of Set 8 | saint-michel-des-saints
# Processing Record 43 of Set 8 | svetlogorsk
# Processing Record 44 of Set 8 | santa helena de goias
# Processing Record 45 of Set 8 | srikakulam
# Processing Record 46 of Set 8 | acapulco
# Processing Record 47 of Set 8 | saint-augustin
# Processing Record 48 of Set 8 | san quintin
# Processing Record 49 of Set 8 | douentza
# Processing Record 50 of Set 8 | shunyi
# Processing Record 1 of Set 9 | baiyin
# Processing Record 2 of Set 9 | ribeira grande
# Processing Record 3 of Set 9 | bjornevatn
# Processing Record 4 of Set 9 | ravar
# Processing Record 5 of Set 9 | amarante do maranhao
# Processing Record 6 of Set 9 | valle de allende
# Processing Record 7 of Set 9 | tari
# Processing Record 8 of Set 9 | dulce grande
# Processing Record 9 of Set 9 | sonari
# Processing Record 10 of Set 9 | salinopolis
# Processing Record 11 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | eyl
# Processing Record 13 of Set 9 | bairiki
# Processing Record 14 of Set 9 | peterhead
# Processing Record 15 of Set 9 | natal
# Processing Record 16 of Set 9 | alyangula
# Processing Record 17 of Set 9 | concordia
# Processing Record 18 of Set 9 | nioro
# Processing Record 19 of Set 9 | merauke
# Processing Record 20 of Set 9 | narasannapeta
# Processing Record 21 of Set 9 | madawaska
# Processing Record 22 of Set 9 | wukari
# Processing Record 23 of Set 9 | parrsboro
# Processing Record 24 of Set 9 | queanbeyan
# Processing Record 25 of Set 9 | donskoye
# Processing Record 26 of Set 9 | muyezerskiy
# Processing Record 27 of Set 9 | ambunti
# Processing Record 28 of Set 9 | kyra
# Processing Record 29 of Set 9 | neyshabur
# Processing Record 30 of Set 9 | stolin
# Processing Record 31 of Set 9 | susehri
# Processing Record 32 of Set 9 | deer lake
# Processing Record 33 of Set 9 | san pedro
# Processing Record 34 of Set 9 | kindu
# Processing Record 35 of Set 9 | talnakh
# Processing Record 36 of Set 9 | walvis bay
# Processing Record 37 of Set 9 | pangai
# Processing Record 38 of Set 9 | bandung
# Processing Record 39 of Set 9 | bubaque
# Processing Record 40 of Set 9 | katobu
# Processing Record 41 of Set 9 | teluknaga
# Processing Record 42 of Set 9 | dalvik
# Processing Record 43 of Set 9 | tuktoyaktuk
# Processing Record 44 of Set 9 | shenjiamen
# Processing Record 45 of Set 9 | loiza
# Processing Record 46 of Set 9 | saint-pierre
# Processing Record 47 of Set 9 | nevsehir
# Processing Record 48 of Set 9 | mangaluru
# Processing Record 49 of Set 9 | goure
# Processing Record 50 of Set 9 | oriximina
# Processing Record 1 of Set 10 | brae
# Processing Record 2 of Set 10 | sakaiminato
# Processing Record 3 of Set 10 | streletskoye
# Processing Record 4 of Set 10 | brokopondo
# Processing Record 5 of Set 10 | samfya
# Processing Record 6 of Set 10 | hanyang
# Processing Record 7 of Set 10 | marathon
# Processing Record 8 of Set 10 | genhe
# Processing Record 9 of Set 10 | bambous virieux
# Processing Record 10 of Set 10 | rajakhera
# Processing Record 11 of Set 10 | beverley
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 13 of Set 10 | colombia
# Processing Record 14 of Set 10 | birjand
# Processing Record 15 of Set 10 | caravelas
# Processing Record 16 of Set 10 | belyy yar
# Processing Record 17 of Set 10 | portland
# Processing Record 18 of Set 10 | podosinovets
# Processing Record 19 of Set 10 | gwadar
# Processing Record 20 of Set 10 | shadegan
# Processing Record 21 of Set 10 | khandbari
# Processing Record 22 of Set 10 | ballina
# Processing Record 23 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | magdagachi
# Processing Record 26 of Set 10 | chastoozerye
# City not found. Skipping...
# Processing Record 27 of Set 10 | koslan
# Processing Record 28 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 10 | bow island
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 10 | zyryanka
# Processing Record 33 of Set 10 | skjervoy
# Processing Record 34 of Set 10 | iturama
# Processing Record 35 of Set 10 | leningradskiy
# Processing Record 36 of Set 10 | sijunjung
# Processing Record 37 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 10 | camacha
# Processing Record 39 of Set 10 | medicine hat
# Processing Record 40 of Set 10 | businga
# Processing Record 41 of Set 10 | snasa
# Processing Record 42 of Set 10 | rincon
# Processing Record 43 of Set 10 | tselinnoye
# Processing Record 44 of Set 10 | guadalupe y calvo
# Processing Record 45 of Set 10 | livno
# Processing Record 46 of Set 10 | sterling
# Processing Record 47 of Set 10 | copiapo
# Processing Record 48 of Set 10 | lempaala
# Processing Record 49 of Set 10 | sakakah
# Processing Record 50 of Set 10 | broome
# Processing Record 1 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 11 | koratla
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | culaman
# Processing Record 5 of Set 11 | bacsay
# Processing Record 6 of Set 11 | ikongo
# Processing Record 7 of Set 11 | hvolsvollur
# Processing Record 8 of Set 11 | velyka lepetykha
# Processing Record 9 of Set 11 | riyadh
# Processing Record 10 of Set 11 | boromo
# Processing Record 11 of Set 11 | keratea
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | ghanzi
# Processing Record 14 of Set 11 | amarwara
# Processing Record 15 of Set 11 | antsirabe
# Processing Record 16 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 11 | chimbote
# Processing Record 18 of Set 11 | olenegorsk
# Processing Record 19 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 20 of Set 11 | chokurdakh
# Processing Record 21 of Set 11 | dunedin
# Processing Record 22 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 11 | horsham
# Processing Record 24 of Set 11 | hay river
# Processing Record 25 of Set 11 | malanje
# Processing Record 26 of Set 11 | kahului
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | binga
# Processing Record 29 of Set 11 | kasongo-lunda
# Processing Record 30 of Set 11 | fengrun
# Processing Record 31 of Set 11 | peniche
# Processing Record 32 of Set 11 | urengoy
# Processing Record 33 of Set 11 | celestun
# Processing Record 34 of Set 11 | san luis
# Processing Record 35 of Set 11 | vaitape
# Processing Record 36 of Set 11 | castro
# Processing Record 37 of Set 11 | okhtyrka
# Processing Record 38 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 11 | uarini
# Processing Record 40 of Set 11 | san cristobal
# Processing Record 41 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 11 | malya
# Processing Record 43 of Set 11 | kieta
# Processing Record 44 of Set 11 | praia
# Processing Record 45 of Set 11 | karapyshi
# Processing Record 46 of Set 11 | veraval
# Processing Record 47 of Set 11 | mweka
# Processing Record 48 of Set 11 | batticaloa
# Processing Record 49 of Set 11 | ibadan
# Processing Record 50 of Set 11 | kosonsoy
# Processing Record 1 of Set 12 | boulder city
# Processing Record 2 of Set 12 | camoapa
# Processing Record 3 of Set 12 | marsa matruh
# Processing Record 4 of Set 12 | pevek
# Processing Record 5 of Set 12 | yilan
# Processing Record 6 of Set 12 | vila franca do campo
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | narsaq
# Processing Record 10 of Set 12 | san clemente
# Processing Record 11 of Set 12 | espanola
# Processing Record 12 of Set 12 | mapiripan
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 | dickinson
# Processing Record 15 of Set 12 | umbertide
# Processing Record 16 of Set 12 | solnechnyy
# Processing Record 17 of Set 12 | sechura
# Processing Record 18 of Set 12 | mezen
# Processing Record 19 of Set 12 | malakal
# Processing Record 20 of Set 12 | oranjestad
# Processing Record 21 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 12 | komsomolskiy
# Processing Record 23 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 12 | mnogovershinnyy
# Processing Record 25 of Set 12 | lowestoft
# Processing Record 26 of Set 12 | sandpoint
# Processing Record 27 of Set 12 | izumo
# Processing Record 28 of Set 12 | andros town
# Processing Record 29 of Set 12 | palmerston
# Processing Record 30 of Set 12 | maarianhamina
# Processing Record 31 of Set 12 | rapid valley
# Processing Record 32 of Set 12 | sanghar
# Processing Record 33 of Set 12 | coihaique
# Processing Record 34 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | alausi
# Processing Record 37 of Set 12 | sinjar
# Processing Record 38 of Set 12 | uyar
# Processing Record 39 of Set 12 | shiraz
# Processing Record 40 of Set 12 | sao felix do xingu
# Processing Record 41 of Set 12 | half moon bay
# Processing Record 42 of Set 12 | ponta delgada
# Processing Record 43 of Set 12 | kushiro
# Processing Record 44 of Set 12 | anori
# Processing Record 45 of Set 12 | golden
# Processing Record 46 of Set 12 | george
# Processing Record 47 of Set 12 | noshiro
# Processing Record 48 of Set 12 | bethanien
# Processing Record 49 of Set 12 | pasighat
# Processing Record 50 of Set 12 | waslala
# Processing Record 1 of Set 13 | kiruna
# Processing Record 2 of Set 13 | bela
# Processing Record 3 of Set 13 | uray
# Processing Record 4 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 5 of Set 13 | whitehorse
# Processing Record 6 of Set 13 | tommot
# Processing Record 7 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 13 | mpongwe
# Processing Record 9 of Set 13 | alofi
# Processing Record 10 of Set 13 | wanning
# Processing Record 11 of Set 13 | susanville
# Processing Record 12 of Set 13 | ostersund
# Processing Record 13 of Set 13 | tahmek
# Processing Record 14 of Set 13 | hambantota
# Processing Record 15 of Set 13 | maldonado
# Processing Record 16 of Set 13 | ati
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | high rock
# Processing Record 19 of Set 13 | kurkino
# Processing Record 20 of Set 13 | beipiao
# Processing Record 21 of Set 13 | gazanjyk
# Processing Record 22 of Set 13 | aksarka
# Processing Record 23 of Set 13 | hibbing
# Processing Record 24 of Set 13 | san vicente
# Processing Record 25 of Set 13 | henties bay
# Processing Record 26 of Set 13 | miguel calmon
# Processing Record 27 of Set 13 | wakkanai
# Processing Record 28 of Set 13 | zhigansk
# Processing Record 29 of Set 13 | loandjili
# Processing Record 30 of Set 13 | dunda
# Processing Record 31 of Set 13 | gombe
# Processing Record 32 of Set 13 | ormara
# Processing Record 33 of Set 13 | boo
# Processing Record 34 of Set 13 | porto novo
# Processing Record 35 of Set 13 | hofn
# Processing Record 36 of Set 13 | thunder bay
# Processing Record 37 of Set 13 | ishimbay
# Processing Record 38 of Set 13 | vao
# Processing Record 39 of Set 13 | salamiyah
# Processing Record 40 of Set 13 | nouadhibou
# Processing Record 41 of Set 13 | puerto narino
# Processing Record 42 of Set 13 | vangaindrano
# Processing Record 43 of Set 13 | atar
# Processing Record 44 of Set 13 | road town
# Processing Record 45 of Set 13 | duz
# City not found. Skipping...
# Processing Record 46 of Set 13 | itaituba
# Processing Record 47 of Set 13 | hovd
# Processing Record 48 of Set 13 | te anau
# Processing Record 49 of Set 13 | klaksvik
# Processing Record 50 of Set 13 | kailua
# Processing Record 1 of Set 14 | saint anthony
# Processing Record 2 of Set 14 | sirsilla
# Processing Record 3 of Set 14 | comodoro rivadavia
# Processing Record 4 of Set 14 | kushmurun
# Processing Record 5 of Set 14 | khandyga
# Processing Record 6 of Set 14 | yerbogachen
# Processing Record 7 of Set 14 | panama city
# Processing Record 8 of Set 14 | grand gaube
# Processing Record 9 of Set 14 | kyzyl-mazhalyk
# Processing Record 10 of Set 14 | tucumcari
# Processing Record 11 of Set 14 | kyrksaeterora
# Processing Record 12 of Set 14 | okhotsk
# Processing Record 13 of Set 14 | kasane
# Processing Record 14 of Set 14 | izberbash
# Processing Record 15 of Set 14 | nome
# Processing Record 16 of Set 14 | margate
# Processing Record 17 of Set 14 | krasnyy chikoy
# Processing Record 18 of Set 14 | kondinskoye
# Processing Record 19 of Set 14 | bagdarin
# Processing Record 20 of Set 14 | sibolga
# Processing Record 21 of Set 14 | sapulpa
# Processing Record 22 of Set 14 | zhangye
# Processing Record 23 of Set 14 | kaohsiung
# Processing Record 24 of Set 14 | muros
# Processing Record 25 of Set 14 | omsukchan
# Processing Record 26 of Set 14 | kantang
# Processing Record 27 of Set 14 | norilsk
# Processing Record 28 of Set 14 | kambove
# Processing Record 29 of Set 14 | mandera
# Processing Record 30 of Set 14 | zaysan
# Processing Record 31 of Set 14 | kozhva
# Processing Record 32 of Set 14 | wa
# City not found. Skipping...
# Processing Record 33 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 34 of Set 14 | gimli
# Processing Record 35 of Set 14 | tarauaca
# Processing Record 36 of Set 14 | namatanai
# Processing Record 37 of Set 14 | moba
# Processing Record 38 of Set 14 | tunxi
# City not found. Skipping...
# Processing Record 39 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 14 | dingle
# Processing Record 41 of Set 14 | galle
# Processing Record 42 of Set 14 | shache
# Processing Record 43 of Set 14 | santa maria
# Processing Record 44 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 14 | tralee
# Processing Record 46 of Set 14 | antalaha
# Processing Record 47 of Set 14 | jinchang
# Processing Record 48 of Set 14 | batar
# Processing Record 49 of Set 14 | springbok
# Processing Record 50 of Set 14 | ambatofinandrahana
# Processing Record 1 of Set 15 | beringovskiy
# Processing Record 2 of Set 15 | tecpan
# Processing Record 3 of Set 15 | palmital
# Processing Record 4 of Set 15 | kenai
# Processing Record 5 of Set 15 | amahai
# Processing Record 6 of Set 15 | canakkale
# Processing Record 7 of Set 15 | nadym
# Processing Record 8 of Set 15 | mokolo
# Processing Record 9 of Set 15 | leogane
# Processing Record 10 of Set 15 | axim
# Processing Record 11 of Set 15 | gilazi
# City not found. Skipping...
# Processing Record 12 of Set 15 | flin flon
# Processing Record 13 of Set 15 | worland
# Processing Record 14 of Set 15 | batagay
# Processing Record 15 of Set 15 | dodge city
# Processing Record 16 of Set 15 | port lincoln
# Processing Record 17 of Set 15 | gornopravdinsk
# Processing Record 18 of Set 15 | evensk
# Processing Record 19 of Set 15 | prainha
# Processing Record 20 of Set 15 | dong xoai
# Processing Record 21 of Set 15 | stanislav
# Processing Record 22 of Set 15 | ladnun
# Processing Record 23 of Set 15 | conceicao do mato dentro
# Processing Record 24 of Set 15 | bardiyah
# Processing Record 25 of Set 15 | zvishavane
# Processing Record 26 of Set 15 | gayny
# Processing Record 27 of Set 15 | yongan
# Processing Record 28 of Set 15 | mitsamiouli
# Processing Record 29 of Set 15 | xudat
# Processing Record 30 of Set 15 | nemuro
# Processing Record 31 of Set 15 | rundu
# Processing Record 32 of Set 15 | ahuimanu
# Processing Record 33 of Set 15 | pemangkat
# Processing Record 34 of Set 15 | yarim
# Processing Record 35 of Set 15 | oban
# Processing Record 36 of Set 15 | kabin buri
# Processing Record 37 of Set 15 | los alamos
# Processing Record 38 of Set 15 | atambua
# Processing Record 39 of Set 15 | mlonggo
# Processing Record 40 of Set 15 | samaro
# Processing Record 41 of Set 15 | rafaela
# Processing Record 42 of Set 15 | laguna
# Processing Record 43 of Set 15 | bowen
# Processing Record 44 of Set 15 | nago
# Processing Record 45 of Set 15 | burnie
# Processing Record 46 of Set 15 | siguiri
# Processing Record 47 of Set 15 | hoquiam
# Processing Record 48 of Set 15 | kargasok
# Processing Record 49 of Set 15 | ilulissat
# Processing Record 50 of Set 15 | coruripe
# Processing Record 1 of Set 16 | krasnoselkup
# Processing Record 2 of Set 16 | mujiayingzi
# Processing Record 3 of Set 16 | shingu
# Processing Record 4 of Set 16 | qianjiang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Challenge 6.1.7
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Pangnirtung  66.1451  -65.7125     42.80        75           0        6.91
# 1        Sitka  57.0531 -135.3300     57.09        77          75        8.05
# 2     Hermanus -34.4187   19.2345     59.81        83         100        6.53
# 3       Albany  42.6001  -73.9662     78.94        48           4       12.57
# 4        Sumbe -11.2061   13.8437     74.44        76          70        4.07
# 5  Deputatskiy  69.3000  139.9000     44.76        80          73        4.61
# 6      Devgarh  25.5333   73.9000     87.66        17           0       12.08
# 7     Shurugwi -19.6702   30.0059     54.48        71          99        5.53
# 8        Bluff -46.6000  168.3333     34.81        76         100        7.90
# 9  Constantine  36.3650    6.6147     96.21        31          40       13.80
#
#   Country Current Description
# 0      CA           clear sky
# 1      US       broken clouds
# 2      ZA     overcast clouds
# 3      US           clear sky
# 4      AO       broken clouds
# 5      RU       broken clouds
# 6      IN           clear sky
# 7      ZW     overcast clouds
# 8      NZ     overcast clouds
# 9      DZ    scattered clouds

# %%
# Challenge 6.1.7
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pangnirtung      CA  66.1451  -65.7125     42.80        75           0
# 1        Sitka      US  57.0531 -135.3300     57.09        77          75
# 2     Hermanus      ZA -34.4187   19.2345     59.81        83         100
# 3       Albany      US  42.6001  -73.9662     78.94        48           4
# 4        Sumbe      AO -11.2061   13.8437     74.44        76          70
# 5  Deputatskiy      RU  69.3000  139.9000     44.76        80          73
# 6      Devgarh      IN  25.5333   73.9000     87.66        17           0
# 7     Shurugwi      ZW -19.6702   30.0059     54.48        71          99
# 8        Bluff      NZ -46.6000  168.3333     34.81        76         100
# 9  Constantine      DZ  36.3650    6.6147     96.21        31          40
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1        8.05       broken clouds
# 2        6.53     overcast clouds
# 3       12.57           clear sky
# 4        4.07       broken clouds
# 5        4.61       broken clouds
# 6       12.08           clear sky
# 7        5.53     overcast clouds
# 8        7.90     overcast clouds
# 9       13.80    scattered clouds

# %%
# Challenge 6.1.7
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
